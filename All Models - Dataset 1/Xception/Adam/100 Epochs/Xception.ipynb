# %% [markdown]
# # Complete Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from tensorflow import keras
from keras.layers import Input, Lambda, Dense, Flatten, Dropout
from keras.models import Model
from tensorflow.keras.applications import Xception
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Keeping Colab Alive

# %% [markdown]
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
#
# var colab = setInterval(ConnectButton,60000);
#
#
# clearInterval(colab)

# %% [markdown]
# ## Downloading Dataset

# %%
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)


if __name__ == "__main__":
    file_id = '1OOb7IoDxjvSjp-rqpr2w-caSmIgOCFA_'
    destination = 'dataset.zip'
    download_file_from_google_drive(file_id, destination)

# %% [markdown]
# ## Unzipping Dataset

# %%
# %%capture
# !unzip dataset.zip

# %% [markdown]
# ##Initializing Parameters

# %%
IMAGE_SIZE = [256, 256, 3]

train_path = 'Dataset/Train'
test_path = 'Dataset/Test'
val_path = 'Dataset/Val'

# %% [markdown]
# ## Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)
val_datagen = ImageDataGenerator(rescale = 1./255)




# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('Dataset/Train',
                                                 target_size = (256, 256),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')


test_set = test_datagen.flow_from_directory('Dataset/Test',
                                            target_size = (256, 256),
                                            batch_size = 32,
                                            class_mode = 'categorical')


val_set = test_datagen.flow_from_directory('Dataset/Val',
                                            target_size = (256, 256),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 3641 images belonging to 2 classes.
# Found 455 images belonging to 2 classes.
# Found 455 images belonging to 2 classes.

# %% [markdown]
# ## InceptionResNetV2

# %%
base_model_xcep = Xception(input_shape=IMAGE_SIZE, weights='imagenet', include_top=False, pooling='max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step

# %%
for layer in base_model_xcep.layers:
    layer.trainable = False

# %% [markdown]
# ## Building Model

# %%
x = base_model_xcep.output
x = Flatten()(x)

# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.5)(x)
# prediction = Dense(2,activation = "sigmoid")(x)
# model_final = Model(base_model_eff0.input,prediction)

prediction = Dense(2, activation='softmax')(x)
final_model = Model(inputs=base_model_xcep.input, outputs=prediction)

# %%
final_model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 127, 127, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 127, 127, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 127, 127, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 125, 125, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 125, 125, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 125, 125, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 125, 125, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 125, 125, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 125, 125, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 125, 125, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 125, 125, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 63, 63, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 63, 63, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 63, 63, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 63, 63, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 63, 63, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 63, 63, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 63, 63, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 63, 63, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 63, 63, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 63, 63, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 32, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 32, 32, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 32, 32, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 32, 32, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 32, 32, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 32, 32, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 16, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 16, 16, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 16, 16, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 16, 16, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 16, 16, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 16, 16, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 16, 16, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 16, 16, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 16, 16, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 16, 16, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 16, 16, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 16, 16, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 16, 16, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 16, 16, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 16, 16, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 16, 16, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 16, 16, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 16, 16, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 16, 16, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 16, 16, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 16, 16, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 16, 16, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 16, 16, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 16, 16, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 16, 16, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 16, 16, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 16, 16, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 16, 16, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 16, 16, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 16, 16, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 16, 16, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 16, 16, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 16, 16, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 16, 16, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 16, 16, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 16, 16, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 16, 16, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 16, 16, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 16, 16, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 16, 16, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 16, 16, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 16, 16, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 16, 16, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 16, 16, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 16, 16, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 16, 16, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 16, 16, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 16, 16, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 16, 16, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 16, 16, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 16, 16, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 16, 16, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 16, 16, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 16, 16, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 16, 16, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 16, 16, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 16, 16, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 16, 16, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 16, 16, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 16, 16, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 16, 16, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 16, 16, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 16, 16, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 16, 16, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 16, 16, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 16, 16, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 16, 16, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 8, 8, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 8, 8, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 8, 8, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 8, 8, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 8, 8, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 8, 8, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 8, 8, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            4098        flatten[0][0]
# ==================================================================================================
# Total params: 20,865,578
# Trainable params: 4,098
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = final_model.fit_generator(
  training_set,
  validation_data=val_set,
  epochs=100,
  steps_per_epoch=len(training_set),
  validation_steps=len(val_set)
)
# Out:
# Epoch 1/100
# 114/114 [==============================] - 175s 1s/step - loss: 0.1389 - accuracy: 0.9465 - val_loss: 0.0540 - val_accuracy: 0.9868
# Epoch 2/100
# 114/114 [==============================] - 163s 1s/step - loss: 0.0495 - accuracy: 0.9825 - val_loss: 0.0601 - val_accuracy: 0.9846
# Epoch 3/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0361 - accuracy: 0.9884 - val_loss: 0.0530 - val_accuracy: 0.9868
# Epoch 4/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0397 - accuracy: 0.9861 - val_loss: 0.0463 - val_accuracy: 0.9890
# Epoch 5/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.0444 - val_accuracy: 0.9890
# Epoch 6/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0343 - accuracy: 0.9871 - val_loss: 0.0386 - val_accuracy: 0.9890
# Epoch 7/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0362 - accuracy: 0.9882 - val_loss: 0.0554 - val_accuracy: 0.9868
# Epoch 8/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0284 - accuracy: 0.9922 - val_loss: 0.0392 - val_accuracy: 0.9890
# Epoch 9/100
# 114/114 [==============================] - 159s 1s/step - loss: 0.0264 - accuracy: 0.9929 - val_loss: 0.0396 - val_accuracy: 0.9890
# Epoch 10/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0242 - accuracy: 0.9920 - val_loss: 0.0829 - val_accuracy: 0.9824
# Epoch 11/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0269 - accuracy: 0.9905 - val_loss: 0.0507 - val_accuracy: 0.9890
# Epoch 12/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.0574 - val_accuracy: 0.9868
# Epoch 13/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0242 - accuracy: 0.9905 - val_loss: 0.0514 - val_accuracy: 0.9890
# Epoch 14/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 0.0423 - val_accuracy: 0.9890
# Epoch 15/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0207 - accuracy: 0.9915 - val_loss: 0.0376 - val_accuracy: 0.9890
# Epoch 16/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0227 - accuracy: 0.9919 - val_loss: 0.0324 - val_accuracy: 0.9890
# Epoch 17/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0142 - accuracy: 0.9962 - val_loss: 0.0435 - val_accuracy: 0.9890
# Epoch 18/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0496 - val_accuracy: 0.9868
# Epoch 19/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0680 - val_accuracy: 0.9912
# Epoch 20/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0156 - accuracy: 0.9964 - val_loss: 0.0392 - val_accuracy: 0.9912
# Epoch 21/100
# 114/114 [==============================] - 163s 1s/step - loss: 0.0166 - accuracy: 0.9955 - val_loss: 0.0624 - val_accuracy: 0.9912
# Epoch 22/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0419 - val_accuracy: 0.9934
# Epoch 23/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0106 - accuracy: 0.9960 - val_loss: 0.0476 - val_accuracy: 0.9890
# Epoch 24/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0100 - accuracy: 0.9952 - val_loss: 0.0449 - val_accuracy: 0.9912
# Epoch 25/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 0.0503 - val_accuracy: 0.9912
# Epoch 26/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 0.0408 - val_accuracy: 0.9934
# Epoch 27/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.0382 - val_accuracy: 0.9934
# Epoch 28/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0331 - val_accuracy: 0.9890
# Epoch 29/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.0569 - val_accuracy: 0.9912
# Epoch 30/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 0.0302 - val_accuracy: 0.9956
# Epoch 31/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0135 - accuracy: 0.9940 - val_loss: 0.0460 - val_accuracy: 0.9912
# Epoch 32/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0517 - val_accuracy: 0.9890
# Epoch 33/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0178 - accuracy: 0.9935 - val_loss: 0.0455 - val_accuracy: 0.9912
# Epoch 34/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0153 - accuracy: 0.9931 - val_loss: 0.0353 - val_accuracy: 0.9912
# Epoch 35/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0143 - accuracy: 0.9941 - val_loss: 0.0766 - val_accuracy: 0.9890
# Epoch 36/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0301 - accuracy: 0.9892 - val_loss: 0.0511 - val_accuracy: 0.9890
# Epoch 37/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0463 - val_accuracy: 0.9912
# Epoch 38/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.0884 - val_accuracy: 0.9868
# Epoch 39/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0326 - val_accuracy: 0.9934
# Epoch 40/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.0450 - val_accuracy: 0.9934
# Epoch 41/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0109 - accuracy: 0.9959 - val_loss: 0.0373 - val_accuracy: 0.9934
# Epoch 42/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0127 - accuracy: 0.9945 - val_loss: 0.0419 - val_accuracy: 0.9956
# Epoch 43/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.0350 - val_accuracy: 0.9868
# Epoch 44/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 0.0506 - val_accuracy: 0.9912
# Epoch 45/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0688 - val_accuracy: 0.9912
# Epoch 46/100
# 114/114 [==============================] - 159s 1s/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.0483 - val_accuracy: 0.9934
# Epoch 47/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0580 - val_accuracy: 0.9912
# Epoch 48/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0740 - val_accuracy: 0.9890
# Epoch 49/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0413 - val_accuracy: 0.9912
# Epoch 50/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0120 - accuracy: 0.9972 - val_loss: 0.1095 - val_accuracy: 0.9824
# Epoch 51/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0119 - accuracy: 0.9950 - val_loss: 0.0377 - val_accuracy: 0.9934
# Epoch 52/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0185 - accuracy: 0.9899 - val_loss: 0.0574 - val_accuracy: 0.9912
# Epoch 53/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0124 - accuracy: 0.9943 - val_loss: 0.0475 - val_accuracy: 0.9912
# Epoch 54/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0685 - val_accuracy: 0.9912
# Epoch 55/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0462 - val_accuracy: 0.9890
# Epoch 56/100
# 114/114 [==============================] - 163s 1s/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0661 - val_accuracy: 0.9912
# Epoch 57/100
# 114/114 [==============================] - 164s 1s/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.0339 - val_accuracy: 0.9934
# Epoch 58/100
# 114/114 [==============================] - 165s 1s/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.0834 - val_accuracy: 0.9912
# Epoch 59/100
# 114/114 [==============================] - 164s 1s/step - loss: 0.0087 - accuracy: 0.9959 - val_loss: 0.1091 - val_accuracy: 0.9868
# Epoch 60/100
# 114/114 [==============================] - 163s 1s/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.0975 - val_accuracy: 0.9890
# Epoch 61/100
# 114/114 [==============================] - 164s 1s/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.0434 - val_accuracy: 0.9934
# Epoch 62/100
# 114/114 [==============================] - 164s 1s/step - loss: 0.0132 - accuracy: 0.9949 - val_loss: 0.0650 - val_accuracy: 0.9912
# Epoch 63/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.0555 - val_accuracy: 0.9912
# Epoch 64/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0115 - accuracy: 0.9953 - val_loss: 0.0509 - val_accuracy: 0.9934
# Epoch 65/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0097 - accuracy: 0.9950 - val_loss: 0.0670 - val_accuracy: 0.9912
# Epoch 66/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0355 - val_accuracy: 0.9912
# Epoch 67/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0729 - val_accuracy: 0.9912
# Epoch 68/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0354 - val_accuracy: 0.9934
# Epoch 69/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.0505 - val_accuracy: 0.9912
# Epoch 70/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0842 - val_accuracy: 0.9912
# Epoch 71/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0474 - val_accuracy: 0.9912
# Epoch 72/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0833 - val_accuracy: 0.9912
# Epoch 73/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0100 - accuracy: 0.9954 - val_loss: 0.0515 - val_accuracy: 0.9890
# Epoch 74/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0569 - val_accuracy: 0.9912
# Epoch 75/100
# 114/114 [==============================] - 159s 1s/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0740 - val_accuracy: 0.9912
# Epoch 76/100
# 114/114 [==============================] - 159s 1s/step - loss: 0.0084 - accuracy: 0.9958 - val_loss: 0.0671 - val_accuracy: 0.9912
# Epoch 77/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.0497 - val_accuracy: 0.9912
# Epoch 78/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0078 - accuracy: 0.9957 - val_loss: 0.0824 - val_accuracy: 0.9912
# Epoch 79/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.0663 - val_accuracy: 0.9912
# Epoch 80/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0131 - accuracy: 0.9947 - val_loss: 0.0525 - val_accuracy: 0.9912
# Epoch 81/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0350 - val_accuracy: 0.9934
# Epoch 82/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0456 - val_accuracy: 0.9912
# Epoch 83/100
# 114/114 [==============================] - 163s 1s/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0421 - val_accuracy: 0.9868
# Epoch 84/100
# 114/114 [==============================] - 164s 1s/step - loss: 0.0235 - accuracy: 0.9912 - val_loss: 0.0428 - val_accuracy: 0.9934
# Epoch 85/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0790 - val_accuracy: 0.9912
# Epoch 86/100
# 114/114 [==============================] - 160s 1s/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0724 - val_accuracy: 0.9912
# Epoch 87/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0446 - val_accuracy: 0.9934
# Epoch 88/100
# 114/114 [==============================] - 161s 1s/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 0.0536 - val_accuracy: 0.9912
# Epoch 89/100
# 114/114 [==============================] - 162s 1s/step - loss: 0.